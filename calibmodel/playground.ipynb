# %%
# %load_ext autoreload
# %matplotlib inline

# %%
import numpy as np
from calibchain import *
from matplotlib.pylab import *
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
import flexvi
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-8cbd6b994811> in <module>()
# ----> 1 import flexvi
#
# ImportError: No module named flexvi

# %%
x_target = np.array([30, 45, 0, 1])

# %%
homog_one(x_target)
# Out:
# array([ 30.,  45.,   0.,   1.])

# %%
x = x_target[0:1]
y = x_target[1:2]
z = x_target[2:3]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
